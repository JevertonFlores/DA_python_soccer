# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/jeverton.rosa/lab_data/DA_python_soccer/data/raw/df_geral_raw.csv')

# %%
df
# Out:
#     Unnamed: 0  Cl            Equipe  MP   V   E   D  GP  GC  GD  ...  \
# 0            0   1         Palmeiras  37  20   9   8  63  32  31  ...
# 1            1   2  Atlético Mineiro  37  19   9   9  51  28  23  ...
# 2            2   3          Flamengo  37  19   9   9  56  41  15  ...
# 3            3   4            Grêmio  37  20   5  12  60  54   6  ...
# 4            4   5     Botafogo (RJ)  37  18  10   9  57  34  23  ...
# 5            5   6        Bragantino  37  17  11   9  48  33  15  ...
# 6            6   7        Fluminense  37  16   8  13  49  44   5  ...
# 7            7   8    Ath Paranaense  37  14  14   9  51  40  11  ...
# 8            8   9     Internacional  37  14  10  13  43  44  -1  ...
# 9            9  10         Fortaleza  37  14   9  14  43  43   0  ...
# 10          10  11         São Paulo  37  13  11  13  39  38   1  ...
# 11          11  12            Cuiabá  37  13   9  15  37  39  -2  ...
# ...

# %%
df_inter = df[df['Equipe'] == 'Internacional']

# %%
df_inter.head()
# Out:
#    Unnamed: 0  Cl         Equipe  MP   V   E   D  GP  GC  GD  ...  Pts/PPJ  \
# 8           8   9  Internacional  37  14  10  13  43  44  -1  ...      141
#
#      xG   xGA  xGD  xGD/90  Últimos 5 Público  Artilheiro da equipe  \
# 8  40.9  46.7 -5.8     -16  E D V V V  10.628    Enner Valencia - 8
#
#          Goleiro Notas
# 8  Sergio Rochet   NaN
#
# [1 rows x 21 columns]

# %%
df_inter.to_csv('C:/Users/jeverton.rosa/lab_data/DA_python_soccer/data/processed/inter.csv')

# %%
import os

# Obtém o diretório de trabalho atual
print(os.getcwd())
# Out:
# C:\Users\jeverton.rosa\lab_data\DA_python_soccer\notebooks
